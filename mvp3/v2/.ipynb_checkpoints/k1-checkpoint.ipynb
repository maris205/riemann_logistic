# %%
import os
import numpy as np
import multiprocessing as mp
import time

# --- 1. 规格定义 ---
TOTAL_STEPS = 10**10      
TARGET_MODES = 200        
NUM_PROCESSES = 64        
SAVE_DIR = "riemann_200_pure"
K_SAMPLES = np.linspace(4.7, 12.7, 64)

# --- 2. 核心算法逻辑：填入你之前的演化代码 ---
def run_riemann_simulation(k, steps, n_modes):
    try:
        # ==========================================
        # ### 核心算法填入处 ###
        # 示例逻辑（请替换为你自己的迭代逻辑）：
        # t = np.arange(steps)
        # aging_term = 1.0 / np.log(t + 2)**2  # 你那个标志性的老化项
        # ... 迭代计算 ...
        # phases = 最终得到的特征相位数组
        # ==========================================
        
        # 假设你的变量名叫 phases
        return phases 
    except Exception as e:
        print(f"Algorithm error for k={k}: {e}")
        return None

# --- 3. 严格的 Worker 函数 (保持不变) ---
def worker(k):
    file_path = os.path.join(SAVE_DIR, f"pure_res_k_{k:.4f}_steps10t10.npy")
    if os.path.exists(file_path): return f"Skip: {k:.4f}"

    phases = run_riemann_simulation(k, TOTAL_STEPS, TARGET_MODES)
    
    if phases is not None and len(phases) >= TARGET_MODES:
        pure_data = np.array(phases[:TARGET_MODES], dtype=np.float64)
        np.save(file_path, pure_data)
        return f"Done: k={k:.4f}"
    return f"Fail: k={k:.4f} returned {type(phases)}"

if __name__ == "__main__":
    if not os.path.exists(SAVE_DIR): os.makedirs(SAVE_DIR)
    print(f">>> 启动 256 核暴力扫描...")
    with mp.Pool(processes=NUM_PROCESSES) as pool:
        results = pool.map(worker, K_SAMPLES)
    for res in results: print(res)
# Out:
# >>> 已创建纯净数据目录: riemann_200_pure
# >>> 启动 256 核暴力扫描 (任务总数: 64)
# >>> 目标规格: 200 模式 | 10000000000 步
#
# ==============================
# Fail: k=4.7000 returned None
# Fail: k=4.8270 returned None
# Fail: k=4.9540 returned None
# Fail: k=5.0810 returned None
# Fail: k=5.2079 returned None
# Fail: k=5.3349 returned None
# Fail: k=5.4619 returned None
# Fail: k=5.5889 returned None
# Fail: k=5.7159 returned None
# Fail: k=5.8429 returned None
# Fail: k=5.9698 returned None
# Fail: k=6.0968 returned None
# Fail: k=6.2238 returned None
# Fail: k=6.3508 returned None
# Fail: k=6.4778 returned None
# Fail: k=6.6048 returned None
# Fail: k=6.7317 returned None
# Fail: k=6.8587 returned None
# Fail: k=6.9857 returned None
# Fail: k=7.1127 returned None
# Fail: k=7.2397 returned None
# Fail: k=7.3667 returned None
# Fail: k=7.4937 returned None
# Fail: k=7.6206 returned None
# Fail: k=7.7476 returned None
# Fail: k=7.8746 returned None
# Fail: k=8.0016 returned None
# Fail: k=8.1286 returned None
# Fail: k=8.2556 returned None
# Fail: k=8.3825 returned None
# Fail: k=8.5095 returned None
# Fail: k=8.6365 returned None
# Fail: k=8.7635 returned None
# Fail: k=8.8905 returned None
# Fail: k=9.0175 returned None
# Fail: k=9.1444 returned None
# Fail: k=9.2714 returned None
# Fail: k=9.3984 returned None
# Fail: k=9.5254 returned None
# Fail: k=9.6524 returned None
# Fail: k=9.7794 returned None
# Fail: k=9.9063 returned None
# Fail: k=10.0333 returned None
# Fail: k=10.1603 returned None
# Fail: k=10.2873 returned None
# Fail: k=10.4143 returned None
# Fail: k=10.5413 returned None
# Fail: k=10.6683 returned None
# Fail: k=10.7952 returned None
# Fail: k=10.9222 returned None
# Fail: k=11.0492 returned None
# Fail: k=11.1762 returned None
# Fail: k=11.3032 returned None
# Fail: k=11.4302 returned None
# Fail: k=11.5571 returned None
# Fail: k=11.6841 returned None
# Fail: k=11.8111 returned None
# Fail: k=11.9381 returned None
# Fail: k=12.0651 returned None
# Fail: k=12.1921 returned None
# Fail: k=12.3190 returned None
# Fail: k=12.4460 returned None
# Fail: k=12.5730 returned None
# Fail: k=12.7000 returned None
# ==============================
# >>> 扫描结束。成功/跳过: 0/64
